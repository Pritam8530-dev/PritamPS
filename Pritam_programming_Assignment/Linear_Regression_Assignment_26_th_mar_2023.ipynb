# %% [markdown]
# #### Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an example of each.

# %% [markdown]
# Ans:

# %% [markdown]
# #### 1.simple linear regression :
#
#
#     1.It has only one independent variable and one dependent variable.
#
#     2.dependent variable is in continous variable .
#
#     3.The mathematical equations i , y = mx + c
#
#     y = output variable
#
#     m = slope or coefficient
#
#     x = input data points /  independent variable
#
#     c = intercept
#
#
#     eg : weight Height dataset
#
#
#
# #### 2.multiple linear regression :
#
#     1.It has more than one independent variable and one dependent variable.
#
#     2.dependent variable is in continous variable .
#
#     3.The mathematical equation is , y = m1x1 + m2x2 + c
#
#     y = output variable
#
#     m1 , m2 = slope or coefficient
#
#     x1 , x2 = input data points / independent variable
#
#     c = intercept
#
#     eg : House price prediction
#
#       No. of rooms    size of rooms    price

# %% [markdown]
# #### Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in a given dataset?

# %% [markdown]
# Ans:

# %% [markdown]
# Assumptions :
#
#     1.The linear relationship between independent variable and dependent variable.
#
#     i.Linear relationship
#
#     ii.Multivariant normality
#
#     iii.No or little multicolinearity
#
#     iv.Homoscedastitcity

# %% [markdown]
# #### Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using a real-world scenario.

# %% [markdown]
# Ans:

# %% [markdown]
# In linear regression ,
#
# y = mx + c
#
#
# y = output variable
#
# m = slope or coefficient
#
# x = independent variable
#
# c = intercept
#
#
# slope = Rate of change of dependent variable with respect to independent variable.
#
# Intercept = value of dependent variable when independent variable is eual to zero (0)
#
#
# consider an example of years of experience and salary data,
#
# salary(y) = 50000 + 5000 * years of experience (x)
#
#
# here ,
#
# if an employee has not an experience but he get 50000 salary.
#
# when he has experience of 1 year the he will get ,
#
# salary(y) = 50000 + 5000 *  1 = 55000
#
#
# when he has experience of 3 year the he will get ,
#
# salary(y) = 50000 + 5000 *  3 = 65000
#
# when experience is increased by 1 year then salary is also increased by 5000 respectively.

# %% [markdown]
# #### Q4. Explain the concept of gradient descent. How is it used in machine learning?

# %% [markdown]
# Ans:

# %% [markdown]
# Gradient descent is the most commonly used for optimize algorithms .
#
# To minimize the errors between actual data points and predicted data points.
#
# It is used to optimize slope and intercept upto global minima.
#
# Global minima : It is the point where error is minimum.
#
# ![Screenshot%20%28438%29.png](attachment:Screenshot%20%28438%29.png)

# %% [markdown]
# #### Q5. Describe the multiple linear regression model. How does it differ from simple linear regression?

# %% [markdown]
# Ans:

# %% [markdown]
# #### 1.Multiple Linear Regression :
#
#     1.Multiple Linear Regression model contains more than one independent vriable and one dependent variable .
#
#     2.dependent variable is in continous variable .
#
#     3.Mthematical equation is ,
#
#     y = m1x1 + m2x2 + c
#
#     y = output variable
#
#     m1 , m2 = slope or coefficient
#
#     x1 , x2 = input data points / independent variable
#
#     c = intercept
#
#     eg : House price prediction
#
#     No. of rooms    size of rooms    price

# %% [markdown]
# #### 2.simple linear regression :
#
# 1.It has only one independent variable and one dependent variable.
#
# 2.dependent variable is in continous variable .
#
# 3.The mathematical equations i , y = mx + c
#
# y = output variable
#
# m = slope or coefficient
#
# x = input data points /  independent variable
#
# c = intercept
#
#
# eg : weight Height dataset

# %% [markdown]
# #### Q6. Explain the concept of multicollinearity in multiple linear regression. How can you detect and address this issue?

# %% [markdown]
# Ans:

# %% [markdown]
# multicollinearity :
#
#     multiple features passing the same amount of information to the output variable.
#
#     so it can creat multicollineairy issue.
#
#     Multicollinearity happens when independent variables in the regression model are highly correlated to each other.
#
#     It makes it hard to interpret of model and also creates an overfitting problem.
#
#     It is a common assumption that people test before selecting the variables into the regression model.

# %% [markdown]
# #### Q7. Describe the polynomial regression model. How is it different from linear regression?

# %% [markdown]
# Ans:

# %% [markdown]
# #### polynomial regression model :
#
#     polynomial regression is used when data is not into linear format.
#
#     data is into curve format.
#
#     degree has not order 1.
#
#     degree is into polynomial.
#
#     polynomial regression has two type ,
#
#     1.simple polynomial regression
#
#     2.multiple polynomial regression
#
#     1.simple polynomial regression :
#
#         It contain one independent variable
#
#         mathematical equation is ,
#
#         y = c0 + c1x^1 + c2x^2 + c3x^3 + .....+cnx
#
#         c0 = intercept
#
#         c1 ,c2 ,c3 ,cn = slope or coefficient
#
#         x = independent variable
#
#
#     2.Multiple linear regression :
#
#         It contain more than one independent variable
#
#         y = c0 + c1x1^1 + c2x2^2 + c3x3^3 +....+cnxn^n
#
#         c0 = intercept
#
#         c1 ,c2 ,c3 ,cn = slope or coefficient
#
#         x1,x2,x3,xn = independent variable
#
#
#
# #### 2.simple linear regression :
#
# 1.It has only one independent variable and one dependent variable.
#
# 2.dependent variable is in continous variable .
#
# 3.The mathematical equations i , y = mx + c
#
# y = output variable
#
# m = slope or coefficient
#
# x = input data points / independent variable
#
# c = intercept
#
# eg : weight Height dataset

# %% [markdown]
# #### Q8. What are the advantages and disadvantages of polynomial regression compared to linear regression? In what situations would you prefer to use polynomial regression?

# %% [markdown]
# Ans:

# %% [markdown]
# Advantages :
#
#     1.works on any size of dataset.
#
#     2.works very well on non linear data.
#
#
# Disadvantages:
#
#     1.We need to choose right polynomial degreee for good bias / variance tradeoff.
#
#
#
# when data is into not linear format then we use polynomial regression.
