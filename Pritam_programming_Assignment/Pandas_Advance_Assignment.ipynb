# %% [markdown]
# #### Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# Ans:

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
list(df.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.skew()
# Out:
# C:\Users\Pritam\AppData\Local\Temp/ipykernel_11708/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64

# %%
pd.Categorical(df)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', ..., 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# Length: 12
# Categories (12, object): ['Age', 'Cabin', 'Embarked', 'Fare', ..., 'Sex', 'SibSp', 'Survived', 'Ticket']

# %%
df['Name'].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# #### DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %% [markdown]
# Ans:

# %%
data = {'A':['john','sam','michel'],
       'B':[23,24,25],
       'C':['Engineer','Engineer','Engineer']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         A   B         C
# 0    john  23  Engineer
# 1     sam  24  Engineer
# 2  michel  25  Engineer

# %%
new_index = [1,3,5]

# %%
df.reindex(new_index , fill_value = 0)
# Out:
#      A   B         C
# 1  sam  24  Engineer
# 3    0   0         0
# 5    0   0         0

# %% [markdown]
# #### Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.

# %% [markdown]
# Ans:

# %%
df = pd.DataFrame(data = {'values':[10,20,30,40,50,60,70]})

# %%
df
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# 5      60
# 6      70

# %%
df1 = df.head(3)

# %%
def calculate_sum():
    
    sum = 0
    
    for i , v in df1.itertuples():
        
        
        sum = sum +v
        
    return 'The sum of first three values are :',sum

calculate_sum()
# Out:
# ('The sum of first three values are :', 60)

# %% [markdown]
# ##### OR

# %%
def calculate_sum_1():
    sum = 0
    
    
    for  i , v in df.itertuples():
        
        if i == 3 :
            
            break
        
    sum = sum + v 
    
print('The sum of first three values are :',sum)

calculate_sum_1()
# Out:
# The sum of first three values are : 60

# %%
df.head(3).sum()
# Out:
# values    60
# dtype: int64

# %% [markdown]
# #### Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %% [markdown]
# Ans:

# %%
data = {'Text':['Hi Hello','How are you','I am good','what abou you']}

# %%
data
# Out:
# {'Text': ['Hi Hello', 'How are you', 'I am good', 'what abou you']}

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#             Text
# 0       Hi Hello
# 1    How are you
# 2      I am good
# 3  what abou you

# %%
import numpy as np
def create_column():
    
    df2['Word_Count'] = df2['Text'].apply(lambda n : len(n.split()))
    
    
create_column()

# %%
df2
# Out:
#             Text  Word_Count
# 0       Hi Hello           2
# 1    How are you           3
# 2      I am good           3
# 3  what abou you           3

# %% [markdown]
# #### OR

# %%
df_article = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/articles.csv" , encoding = 'latin1')

# %%
df_article = df_article.iloc[:,:1]

# %%
df_article = pd.DataFrame(df_article)

# %%
df_article.rename(columns = {'Article': 'Text'} , inplace = True)

# %%
df_article.head()
# Out:
#                                                 Text
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...

# %%
def calculate_word():
    
    df_article['Word_count'] = df_article['Text'].apply(lambda n : len(n.split()))
    
                               
    
    
    

calculate_word()

# %%
df_article
# Out:
#                                                  Text  Word_count
# 0   Data analysis is the process of inspecting and...          76
# 1   The performance of a machine learning algorith...          56
# 2   You must have seen the news divided into categ...          70
# 3   When there are only two classes in a classific...          66
# 4   The Multinomial Naive Bayes is one of the vari...          96
# 5   You must have seen the news divided into categ...          70
# 6   Natural language processing or NLP is a subfie...          82
# 7   By using a third-party application or API to m...          76
# 8   Twitter is one of the most popular social medi...          82
# 9   The squid game is currently one of the most tr...          87
# 10  Computer Vision is one of the fields of Artifi...          80
# 11  Python is one of the most popular programming ...          97
# 12  API stands for Application Programming Interfa...          98
# ...

# %% [markdown]
# #### Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# Ans:

# %% [markdown]
# #### size : size is use for to show how many elements present in DataFrame

# %%
df_article.size
# Out:
# 68

# %% [markdown]
# #### shape : shape is use for to show How many number of rows and columns in DataFrame

# %%
df_article.shape
# Out:
# (34, 2)

# %% [markdown]
# ##### Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# Ans :

# %%
df = pd.read_excel('airline.xls')

# %%
df
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %% [markdown]
# #### Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
#
# #### The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %% [markdown]
# Ans:

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/maranyil/Node-employees-CSV/main/employees.csv')

# %%
df
# Out:
#    id first_name  last_name                      email      ip_address
# 0   1  Henryetta    Sweeney      hsweeney0@latimes.com  247.180.114.45
# 1   2   Patricio    Stranio         pstranio1@dell.com  78.193.175.227
# 2   3      Lonna  Del Dello          ldeldello2@a8.net  153.40.129.182
# 3   4       Brod    Francom  bfrancom3@telegraph.co.uk   93.216.83.226
# 4   5     Dennis   Dahlborg         ddahlborg4@ihg.com  45.186.226.177
# 5   6     Mannie     Bunney           mbunney5@ted.com  88.181.137.136
# 6   7     Nichol     Bredee          nbredee6@narod.ru    120.169.3.78
# 7   8      Korie    Stelfox        kstelfox7@lycos.com    164.71.32.87
# 8   9    Brandtr       Poge            bpoge8@wisc.edu  158.41.144.205
# 9  10     Andres    Zecchii       azecchii9@zimbio.com   36.85.142.152

# %%
def extract_username():
    
    
    
    df['username'] = pd.DataFrame(df['email'].apply(lambda n : n.split('@')[0]))
    
    
extract_username()

# %%
df
# Out:
#    id first_name  last_name                      email      ip_address  \
# 0   1  Henryetta    Sweeney      hsweeney0@latimes.com  247.180.114.45
# 1   2   Patricio    Stranio         pstranio1@dell.com  78.193.175.227
# 2   3      Lonna  Del Dello          ldeldello2@a8.net  153.40.129.182
# 3   4       Brod    Francom  bfrancom3@telegraph.co.uk   93.216.83.226
# 4   5     Dennis   Dahlborg         ddahlborg4@ihg.com  45.186.226.177
# 5   6     Mannie     Bunney           mbunney5@ted.com  88.181.137.136
# 6   7     Nichol     Bredee          nbredee6@narod.ru    120.169.3.78
# 7   8      Korie    Stelfox        kstelfox7@lycos.com    164.71.32.87
# 8   9    Brandtr       Poge            bpoge8@wisc.edu  158.41.144.205
# 9  10     Andres    Zecchii       azecchii9@zimbio.com   36.85.142.152
#
#      username
# 0   hsweeney0
# 1   pstranio1
# 2  ldeldello2
# 3   bfrancom3
# 4  ddahlborg4
# 5    mbunney5
# 6    nbredee6
# 7   kstelfox7
# 8      bpoge8
# 9   azecchii9

# %% [markdown]
# #### Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.
#
# #### For example, if df contains the following values:
#
#   A B C
#
# 0 3 5 1
#
# 1 8 2 7
#
# 2 6 9 4
#
# 3 2 3 5
#
# 4 9 1 2

# %% [markdown]
# Ans:

# %%
Data = {'A':[3,8,6,2,9], 'B':[5,2,9,3,1],'C':[1,7,4,5,2]}

# %%
df = pd.DataFrame(Data)

# %%
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def filter_records():
    
    df1 = df[(df['A']>5) & (df['B'] < 10)]
    print(df1)
    
#print(df1)
filter_records()
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
df1 = df[(df['A']>5) & (df['B'] < 10)]

# %%
df1
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# #### Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %% [markdown]
# Ans:

# %%
df_values = pd.DataFrame(data = {'values':[10,20,30,40,50,60,70]})

# %%
df_values
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# 5      60
# 6      70

# %%
def mean_median_std():
    
    print('Mean of dataframe is :',df_values.mean())
    
    print('Median of dataframe is :',df_values.median())
    
    print('standerd deviation of dataframe is :', df_values.std())
    
mean_median_std()
# Out:
# Mean of dataframe is : values    40.0
# dtype: float64
# Median of dataframe is : values    40.0
# dtype: float64
# standerd deviation of dataframe is : values    21.602469
# dtype: float64

# %%
df_values.describe()
# Out:
#           values
# count   7.000000
# mean   40.000000
# std    21.602469
# min    10.000000
# 25%    25.000000
# 50%    40.000000
# 75%    55.000000
# max    70.000000

# %% [markdown]
# #### Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day

# %% [markdown]
# Ans :

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mehul90/NSE_TRADER/master/yahoo_data/RELIANCE.NS.csv')

# %%
df.rename(columns = {'Adj Close':'Sales'} , inplace = True)

# %%
df
# Out:
#             Date       Sales
# 0     2000-01-03   16.448257
# 1     2000-01-04   17.765039
# 2     2000-01-05   18.461018
# 3     2000-01-06   19.235373
# 4     2000-01-07   20.555416
# ...          ...         ...
# 4469  2017-10-23  939.750000
# 4470  2017-10-24  934.250000
# 4471  2017-10-25  939.900024
# 4472  2017-10-26  947.400024
# 4473  2017-10-27  929.849976
#
# [4474 rows x 2 columns]

# %%
def Moving_Average():
    
    
    df['MovingAverage'] = df['Sales'].rolling(7).mean()

# %%
df
# Out:
#             Date       Sales
# 0     2000-01-03   16.448257
# 1     2000-01-04   17.765039
# 2     2000-01-05   18.461018
# 3     2000-01-06   19.235373
# 4     2000-01-07   20.555416
# ...          ...         ...
# 4469  2017-10-23  939.750000
# 4470  2017-10-24  934.250000
# 4471  2017-10-25  939.900024
# 4472  2017-10-26  947.400024
# 4473  2017-10-27  929.849976
#
# [4474 rows x 2 columns]

# %%
Moving_Average()

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#             Date       Sales  MovingAverage
# 6     2000-01-11   18.853092      18.782611
# 7     2000-01-12   19.715717      19.249391
# 8     2000-01-13   20.378981      19.622811
# 9     2000-01-14   20.669798      19.938351
# 10    2000-01-17   20.176401      20.072784
# ...          ...         ...            ...
# 4469  2017-10-23  939.750000     884.964286
# 4470  2017-10-24  934.250000     898.407139
# 4471  2017-10-25  939.900024     908.000000
# 4472  2017-10-26  947.400024     918.135716
# 4473  2017-10-27  929.849976     925.714286
#
# [4064 rows x 3 columns]

# %% [markdown]
# #### Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.Monday, Tuesday) corresponding to each date in the 'Date' column.
#
# For example, if df contains the following values:
#
#    Date
#
# 0 2023-01-01
#
# 1 2023-01-02
#
# 2 2023-01-03
#
# 3 2023-01-04
#
# 4 2023-01-05
#
#
# Your function should create the following DataFrame:
#
#
#      Date    Weekday
#
# 0 2023-01-01 Sunday
#
# 1 2023-01-02 Monday
#
# 2 2023-01-03 Tuesday
#
# 3 2023-01-04 Wednesday
#
# 4 2023-01-05 Thursday
#
# The function should return the modified DataFrame.

# %% [markdown]
# Ans:

# %%
data = {'Date':['2023-01-01',

 '2023-01-02',

 '2023-01-03',

 '2023-01-04',

 '2023-01-05']}

# %%
data
# Out:
# {'Date': ['2023-01-01',
#   '2023-01-02',
#   '2023-01-03',
#   '2023-01-04',
#   '2023-01-05']}

# %%
df_date = pd.DataFrame(data)

# %%
df_date
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
def day_column():
    df_date['Date'] = pd.to_datetime(df_date['Date'])
    
    df_date['Weekday'] = df_date['Date'].dt.day_name()
    
day_column()

# %%
df_date
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# #### Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'

# %% [markdown]
# Ans:

# %%
data = {'Date':['2023-01-01',

 '2023-01-02',

 '2023-01-03',

 '2023-01-04',

 '2023-01-05']}

# %%
df_datetime = pd.DataFrame(data)

# %%
df_datetime
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
def select_dates():
    
    start_date = '2023-01-01'
    end_date = '2023-01-31'
    
    print(df_datetime[(df_datetime['Date'] > start_date) & (df_datetime['Date'] <= end_date)])
    
select_dates()
# Out:
#          Date
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
df_datetime_1 = df_datetime[(df_datetime['Date'] > start_date) & (df_datetime['Date'] <= end_date)]

# %%
df_datetime_1
# Out:
#          Date
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %% [markdown]
# #### Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# Ans:

# %%
import pandas as pd
