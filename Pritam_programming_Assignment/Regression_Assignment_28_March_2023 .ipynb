# %% [markdown]
# #### Q1. What is Ridge Regression, and how does it differ from ordinary least squares regression?

# %% [markdown]
# Ans:

# %% [markdown]
# 1.Ridge Regression is also called as L2 Regularization.
#
# 2.Ridge Regression is used for reduce overfitting.
#
#
# overfitting is the well perform on training data and poor perform on testing data / new data.
#
# #### Ridge Regression =  1 / n * (yact - ypred)^2 + lambda*(slope)^2
#
# yact = Actual Output Data Points
#
# ypred = Prediction Output Data Points
#
# lambda = hyperparameter
#
# lambda = 1
#
#
# It error not make as zero . It said to keep some error.
#
# lambda is increases then slope get decrease.

# %% [markdown]
# ![Screenshot%20%28442%29.png](attachment:Screenshot%20%28442%29.png)

# %% [markdown]
# #### Q2. What are the assumptions of Ridge Regression?

# %% [markdown]
# Ans:

# %% [markdown]
# ##### Assumptions of ridge regression is same as the linear regression.
#
# 1.Linear Relationship between independent variable and dependent variable
#
# 2.Multivariant Normality.
#
# 3.No or little multicollinearity
#
# 4.Homoscadisticity

# %% [markdown]
# #### Q3. How do you select the value of the tuning parameter (lambda) in Ridge Regression?

# %% [markdown]
# Ans:

# %% [markdown]
# Selecting a good value for λ is critical. When λ=0, the penalty term has no effect, and ridge regression will produce
#
# the classical least square coefficients. However, as λ increases to infinite, the impact of the shrinkage penalty grows,
#
# and the ridge regression coefficients will get close zero.
#
# In other words ,
#
# when λ=0 that time gradiant descent at global minima. when λ is increases then slope will get towards zero.

# %% [markdown]
# #### Q4. Can Ridge Regression be used for feature selection? If yes, how?

# %% [markdown]
# Ans:

# %% [markdown]
# One of the most important things about ridge regression is that without wasting any information about predictions
#
# it tries to determine variables that have exactly zero effects. Ridge regression is popular because it uses regularization
#
# for making predictions and regularization is intended to resolve the problem of overfitting. We mainly find that overfitting
#
# is where the size of data is very large and ridge regression works by penalizing the coefficient of features and it also
#
# minimizes the errors in prediction.
#
# Talking about the other methods of feature importance they directly nullify the effect of less competent features.
#
# If we believe that some of the coefficients have zero effect using ridge regression we can build a better model by
#
# providing Bayesian priors for regression coefficients. For example, if we know that any of the coefficients have zero
#
# effect but which one has it we don’t know then we can use a prior with a ridge to know about the effect of every
#
# coefficient.  Let’s see how we can implement ridge for feature selection.

# %% [markdown]
# #### Q5. How does the Ridge Regression model perform in the presence of multicollinearity?

# %% [markdown]
# Ans:

# %% [markdown]
# Multicollinearity happens when predictor variables exhibit a correlation among themselves.
#
# Ridge regression aims at reducing the standard error by adding some bias in the estimates of the regression.
#
# The reduction of the standard error in regression estimates significantly increases the reliability of the estimates.

# %% [markdown]
# #### Q6. Can Ridge Regression handle both categorical and continuous independent variables?

# %% [markdown]
# Ans:

# %% [markdown]
# No. Special characteristic of Ridge regression is it works fine in presence of multicollinearity
#
# but with a continuous dependent variable.

# %% [markdown]
# #### Q7. How do you interpret the coefficients of Ridge Regression?

# %% [markdown]
# Ans:

# %% [markdown]
# The ridge coefficients are a reduced factor of the simple linear regression coefficients and
#
# thus never attain zero values but very small values. The lasso coefficients become zero in a certain range and are
#
# reduced by a constant factor, which explains their low magnitude in comparison to the ridge.
#
# In other words ,
#
# In the ridge regression , this is used for to reduce overfitting. Here it not remove entire error . It kept some error.
#
# means slope not reaches to zero.
#
# In the lasso regression , this is used for to feature selection. Here it remove those feature whose are not corelate with
#
# output variable. means slope or coefficient are reach towards zero.

# %% [markdown]
# #### Q8. Can Ridge Regression be used for time-series data analysis? If yes, how?

# %% [markdown]
# Ans:

# %% [markdown]
# Yes . The ridge regression technique can be used to predict time-series.
#
# Ridge regression (RR) can also solve the multicollinearity problem that exists in linear regression.
